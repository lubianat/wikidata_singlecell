# %% [markdown]
# First, we will get the Single cell studies database:

# %%
import pandas as pd
data = pd.read_csv('http://nxn.se/single-cell-studies/data.tsv', sep='\t')

# %%
data.head(3)
# Out:
#               Shorthand                            DOI  \
# 0      Cauli et al PNAS        10.1073/pnas.97.11.6144
# 1     Malnic et al Cell  10.1016/S0092-8674(00)80581-4
# 2  Tietjen et al Neuron  10.1016/S0896-6273(03)00229-0
#
#                                              Authors  \
# 0  B. Cauli, J. T. Porter, K. Tsuzuki, B. Lambole...
# 1  Bettina Malnic, Junzo Hirono, Takaaki Sato, Li...
# 2  Ian Tietjen, Jason M. Rihel, Yanxiang Cao, Geo...
#
#                                            Journal  \
# 0  Proceedings of the National Academy of Sciences
# 1                                             Cell
# 2                                           Neuron
#
#                                                Title      Date bioRxiv DOI  \
# 0  Classification of fusiform neocortical interne...  20020726           -
# 1             Combinatorial Receptor Codes for Odors  20040410           -
# 2  Single-Cell Transcriptional Analysis of Neuron...  20040415           -
#
#   Reported cells total      Organism Tissue  ... Developmental stage  \
# 0                   85           Rat  Brain  ...          21-27 days
# 1                   18         Mouse  Brain  ...                 NaN
# 2                   37  Human, Mouse  Brain  ...                 NaN
#
#   Number of reported cell types or clusters Cell clustering Pseudotime  \
# 0                                       3.0             Yes         No
# 1                                       NaN             NaN        NaN
# 2                                       6.0             NaN        NaN
#
#   RNA Velocity  PCA tSNE H5AD location    Isolation  \
# 0           No  Yes   No           NaN  Patch-clamp
# 1          NaN  NaN  NaN           NaN          NaN
# 2          NaN  NaN  NaN           NaN  Manual, LCM
#
#   BC --> Cell ID _OR_ BC --> Cluster ID
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
#
# [3 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['Shorthand', 'DOI', 'Authors', 'Journal', 'Title', 'Date',
#        'bioRxiv DOI', 'Reported cells total', 'Organism', 'Tissue',
#        'Technique', 'Data location', 'Panel size', 'Measurement',
#        'Cell source', 'Disease', 'Contrasts', 'Developmental stage',
#        'Number of reported cell types or clusters', 'Cell clustering',
#        'Pseudotime', 'RNA Velocity', 'PCA', 'tSNE', 'H5AD location',
#        'Isolation', 'BC --> Cell ID _OR_ BC --> Cluster ID'],
#       dtype='object')

# %% [markdown]
# The idea is to reconcile interesting information to Wikidata. The following columns are considered interesting:

# %%
cols_of_interest = ["DOI", "Organism", "Tissue", "Technique", "Data location" ]

# %% [markdown]
# The idea is to reconcile interesting information to Wikidata. The following columns are considered interesting:

# %%
data = data[cols_of_interest]

# %%
data
# Out:
#                                 DOI      Organism        Tissue  \
# 0           10.1073/pnas.97.11.6144           Rat         Brain
# 1     10.1016/S0092-8674(00)80581-4         Mouse         Brain
# 2     10.1016/S0896-6273(03)00229-0  Human, Mouse         Brain
# 3             10.1093/cercor/bhj081           Rat         Brain
# 4                10.1093/nar/gkl050         Mouse           ICM
# ...                             ...           ...           ...
# 1214     10.1186/s13059-021-02267-5         Human       Culture
# 1215     10.1038/s42003-020-01625-6         Human  Blood, Tumor
# 1216            10.7554/eLife.62586           NaN           NaN
# 1217           10.3390/biom11020177         Human       Culture
# 1218      10.3389/fimmu.2020.594658         Human           NaN
#
#                Technique Data location
# 0             sc-RT-mPCR           NaN
# 1                    PCR           NaN
# 2                    PCR           NaN
# 3             sc-RT-mPCR           NaN
# 4     aRNA amplification       GSE4309
# ...                  ...           ...
# 1214            Chromium     GSE142392
# 1215            Chromium     GSE121638
# 1216                 NaN           NaN
# 1217                 NaN           NaN
# 1218                 NaN           NaN
#
# [1219 rows x 5 columns]

# %%
dois = data["DOI"]
doi_string = " ".join(dois)

query = """
SELECT ?doi ?item  ?itemLabel
WHERE {
  {
    SELECT ?item ?normalized_doi WHERE {
      VALUES ?doi {
      
      """ + doi_string +"""
        
      }
      BIND(UCASE(?doi) AS ?normalized_doi)
      # ?item wdt:P356 ?normalized_doi.
    }
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
"""
